# %% [markdown]
# <a href="https://colab.research.google.com/github/Mulac/TDA-SentimentAnalysis/blob/master/NaiveBayesFrank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install tweet-preprocessor 
import preprocessor as p
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
# Out:
# Collecting tweet-preprocessor
#   Downloading https://files.pythonhosted.org/packages/17/9d/71bd016a9edcef8860c607e531f30bd09b13103c7951ae73dd2bf174163c/tweet_preprocessor-0.6.0-py3-none-any.whl
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Tweets.csv')
text = df['text']
cleaned_text = []
for i in text:
  #result = ''.join([j for j in i if not j.isdigit()])
  cleaned_text.append(p.clean(i))
print(p.clean('@VirginAmerica yes, nearly every time I fly VX this â€œear wormâ€ wonâ€™t go away :)'))
#cleaned_text.shape
cleaned_text

# %%
from sklearn.feature_extraction.text import CountVectorizer 

cv = CountVectorizer()
cv_score = cv.fit_transform(cleaned_text)
#print(cv.get_feature_names())
print(cv_score.shape)
#print(cv.vocabulary_)
# Out:
# ['00', '000', '000419', '00a', '00am', '00p', '00pm', '01', '0185', '01pm', '02', '0200', '03', '04', '05', '05am', '05pm', '07', '07p', '08', '0985', '10', '100', '1000', '1000cost', '1038', '1051', '108639', '10p', '10pm', '10voucherwhatajoke', '11', '1130', '1153', '1170', '118', '12', '120', '1200', '1230', '125', '12h', '13', '130', '1300', '13ewr', '13pm', '14', '145s', '14am', '15', '150', '154', '157', '1571aus', '159', '15am', '15p', '16', '1600', '1629', '165', '16mo', '17', '170', '174', '179', '17pm', '18', '180', '188', '19', '192', '1966', '19b', '19pm', '1hr', '1k', '1m', '1per', '1st', '20', '200', '200fee', '2012', '2015', '202', '209', '20min', '20pm', '21', '21l', '21p', '22', '2210', '2247', '2275', '23', '23sep', '24', '2440', '25', '250', '250k', '26', '26pm', '26th', '27', '275', '28', '285', '2888155964', '29', '297', '299', '2990176298', '2mm', '2morrow', '2nd', '2of2', '2x', '30', '300', '3001408092', '3001885409', '300rt', '304', '3040', '30a', '30am', '30mins', '30pm', '30th', '31', '320', '324', '329', '33', '3312', '335', '337', '34', '3499', '34pm', '35', '350', '358', '35pm', '36', '360', '362', '375', '38', '382', '3860', '3880', '389', '39', '40', '400', '400er', '400s', '40am', '40pm', '41', '416', '41am', '42', '428', '4322', '433', '44', '440', '4473', '44pm', '45', '450', '45am', '45hrs', '45pm', '464', '4651', '47', '475', '48', '4840', '49', '4am', '4that', '50', '500', '5084773604', '50am', '50k', '50pm', '51', '514', '51pm', '53', '539', '544', '547', '54pm', '55', '550', '55558000', '55am', '55pm', '56', '566', '57', '5722', '574', '57am', '58', '59', '59pm', '5sep', '60', '600', '6000', '606', '631', '65', '6500', '653', '675', '6hrs', '6sep', '70', '700', '703', '725', '73', '7300', '737', '7498', '75', '750', '77', '777', '779', '788', '79', '795', '7x8', '80', '800', '800w', '81', '8441639', '856', '89', '891', '89ish', '8am', '8b', '8h4', '8pm', '90', '900', '900s', '90min', '918j_a', '919', '95', '99', '_0', '_exact_', 'a1', 'a15', 'a18', 'a20', 'a3', 'a30', 'a319', 'a320', 'a321', 'a330', 'a380s', 'a3zz0f', 'a4', 'a49', 'a587cw', 'a60', 'a8', 'a8c', 'a9', 'aa', 'aa104', 'aa106', 'aa1061', 'aa1103', 'aa111', 'aa1119', 'aa1224', 'aa1237', 'aa1344', 'aa138', 'aa1401', 'aa1458', 'aa1469', 'aa153', 'aa157', 'aa1657', 'aa1675', 'aa1679', 'aa1691', 'aa199', 'aa200', 'aa215', 'aa223', 'aa2334', 'aa2401', 'aa2402', 'aa
imal': 5907, 'iconography': 4653, 'such': 8857, 'great': 4169, 'deal': 2597, 'already': 655, 'thinking': 9197, 'my': 6105, 'nd': 6181, 'haven': 4355, 'even': 3371, 'gone': 4115, 'on': 6438, 'st': 8657, 'yet': 10480, 'skies': 8387, 'again': 535, 'all': 632, 'from': 3910, 'travel': 9422, 'thanks': 9160, 'sfo': 8217, 'pdx': 6731, 'schedule': 8052, 'still': 8742, 'mia': 5864, 'excited': 3415, 'first': 3685, 'cross': 2455, 'country': 2375, 'lax': 5315, 'mco': 5760, 'heard': 4382, 'nothing': 6319, 'but': 1601, 'things': 9195, 'virgin': 10045, 'america': 685, 'flew': 3718, 'nyc': 6361, 'last': 5288, 'week': 10192, 'couldn': 2364, 'fully': 3950, 'sit': 8362, 'seat': 8104, 'due': 3082, 'two': 9542, 'large': 5282, 'gentleman': 4028, 'either': 3178, 'side': 8318, 'help': 4406, 'be': 1182, 'amazingly': 676, 'awesome': 1044, 'bos': 1425, 'fll': 3764, 'please': 6906, 'want': 10129, 'with': 10328, 'why': 10274, 'are': 854, 'fares': 3570, 'may': 5742, 'over': 6557, 'three': 9225, 'times': 9276, 'more': 6022, 'other': 6518, 'carriers': 1735, 'when': 10245, 'available': 1015, 'select': 8148, 'love': 5566, 'graphic': 4161, 'hipster': 4463, 'innovation': 4850, 'feel': 3614, 'brand': 1466, 'will': 10290, 'making': 5656, 'gt': 4218, 'las': 5286, 'non': 6276, 'stop': 8762, 'permanently': 6776, 'anytime': 778, 'soon': 8536, 'guys': 4258, 'messed': 5846, 'up': 9855, 'seating': 8109, 'reserved': 7689, 'friends': 3905, 'gave': 4008, 'free': 3887, 'internet': 4931, 'status': 8708, 'match': 5733, 'program': 7168, 'applied': 815, 'been': 1209, 'weeks': 10197, 'called': 1664, 'emailed': 3205, 'no': 6269, 'response': 7710, 'happened': 4320, 'ur': 9880, 'vegan': 9991, 'food': 3811, 'options': 6487, 'at': 944, 'least': 5343, 'say': 8023, 'site': 8363, 'won': 10352, 'able': 365, 'eat': 3138, 'anything': 777, 'next': 6232, 'hrs': 4589, 'miss': 5944, 'don': 2982, 'worry': 10389, 'we': 10172, 'll': 5471, 'together': 9312, 'very': 10018, 'can': 1678, 'get': 4043, 'any': 769, 'cold': 2060, 'air': 573, 'vents': 10003, 'ewr': 3397, 'middle': 5871, 'red': 7473, 'eye': 3503, 'noob': 6289, 'maneuver': 5677, 'hi': 4439, 'just': 5139, 'bked': 1327, 'cool': 2327, 'birthday': 1311, 'add': 462, 'elevate': 3188, 'entered': 3283, 'name': 6143, 'during': 3098, 'booking': 1404, 'problems': 7139, 'hours': 4575, 'operation': 6471, 'club': 2018, 'posted': 6994, 'online': 6450, 'current': 2501, 'left': 5352, 'expensive': 3461, 'headphones': 4377, 'iad': 4639, 'one': 6444, 'answering': 757, ' ...

# %%
x_train, x_test, y_train, y_test = train_test_split(cv_score, df.airline_sentiment,
                                                    test_size = 0.3, random_state = 88)

# %%
x_train.shape
# Out:
# (10248, 10536)

# %%
x_test.shape
# Out:
# (4392, 10536)

# %%
classifier = MultinomialNB()

# %%
classifier.fit(x_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
number_correct = (y_test == classifier.predict(x_test)).sum()

# %%
number_correct
# Out:
# 3384

# %%
number_incorrect = y_test.size - number_correct

# %%
number_incorrect
# Out:
# 1008

# %%
classifier.score(x_test, y_test)
# Out:
# 0.7704918032786885

# %%
print(classifier.predict(cv.transform(['boring'])))
# Out:
# ['negative']
